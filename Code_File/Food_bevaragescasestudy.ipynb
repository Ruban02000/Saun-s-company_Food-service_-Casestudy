# %% [markdown]
# ## Shauns Food and Beverage Services

# %% [markdown]
# ### Importing Libraries and Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Restaurant Data

# %%
## importing data from shauns food and beverage services 

Restaurant_Data = pd.read_excel(r"D:\Data_analysis_Projects\Saun's company_Food service_ Casestudy\Data\Restaurant Spends and Share.xlsx")

# %%
Restaurant_Data.head()
# Out:
#                NAME         CITY STATE    ZIP  ZIP_PLUS4  COUNTY_CODE  \
# 0        APPLEBEE'S    POTTSTOWN    PA  19464        NaN      42091.0
# 1  STANS RESTAURANT  SAN LEANDRO    CA  94577     3236.0       6001.0
# 2       THANH THANH      OAKLAND    CA  94606     2978.0       6001.0
# 3    DOMINO'S PIZZA      WENDELL    NC  27591     6904.0      37183.0
# 4  NINNA RESTAURANT      OAKLAND    CA  94611     5221.0       6001.0
#
#   COUNTY_NAME     MSA                                     MARKET_SEGMENT  \
# 0  MONTGOMERY  6162.0       FSR - TRADITIONAL RESTAURANTS, CASUAL DINING
# 1     ALAMEDA  7362.0       FSR - TRADITIONAL RESTAURANTS, CASUAL DINING
# 2     ALAMEDA  7362.0       FSR - TRADITIONAL RESTAURANTS, CASUAL DINING
# 3        WAKE  6640.0  LSR - QUICK SERVICE RESTAURANTS, FAST FOOD, SN...
# 4     ALAMEDA  7362.0       FSR - TRADITIONAL RESTAURANTS, CASUAL DINING
#
#           SIMPLIFIED_MENU  ... AVERAGE_CHECK NUMBER_OF_ROOMS  \
# ...

# %%
#Checking the data types and null values
Restaurant_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   NAME                                   1000 non-null   object
#  1   CITY                                   1000 non-null   object
#  2   STATE                                  1000 non-null   object
#  3   ZIP                                    1000 non-null   int64
#  4   ZIP_PLUS4                              962 non-null    float64
#  5   COUNTY_CODE                            999 non-null    float64
#  6   COUNTY_NAME                            999 non-null    object
#  7   MSA                                    826 non-null    float64
#  8   MARKET_SEGMENT                         1000 non-null   object
#  9   SIMPLIFIED_MENU                        1000 non-null   object
# ...

# %%
#Checking some basic statistics of the dataset
Restaurant_Data.describe()
# Out:
#                 ZIP    ZIP_PLUS4   COUNTY_CODE          MSA  \
# count   1000.000000   962.000000    999.000000   826.000000
# mean   49922.537000  4136.732848  28399.210210  4645.102906
# std    30092.474019  2344.678645  16242.608966  2542.079580
# min     1001.000000     1.000000   1003.000000   120.000000
# 25%    23332.500000  2288.750000  12099.000000  2162.000000
# 50%    43544.000000  3623.500000  29071.000000  4700.000000
# 75%    78451.000000  5616.250000  42080.000000  6640.000000
# max    99701.000000  9900.000000  56033.000000  9320.000000
#
#        FOOD_BEVERAGE_PURCHASE  FOOD_PURCHASE  BEVERAGE_PURCHASE  \
# count            8.890000e+02   8.890000e+02         889.000000
# mean             2.225230e+05   1.958903e+05       26632.674378
# std              2.155446e+05   1.950944e+05       26123.888311
# min              2.384444e+04   1.729385e+04        1764.301190
# 25%              8.839871e+04   7.858661e+04        8016.614086
# ...

# %%
Restaurant_Data.describe(include="object")
# Out:
#              NAME     CITY STATE  COUNTY_NAME  \
# count        1000     1000  1000          999
# unique        750      695    49          421
# top     STARBUCKS  CHICAGO    CA  LOS ANGELES
# freq           37       11   129           28
#
#                                       MARKET_SEGMENT         SIMPLIFIED_MENU  \
# count                                           1000                    1000
# unique                                            26                      20
# top     FSR - TRADITIONAL RESTAURANTS, CASUAL DINING  PIZZA, PASTA & ITALIAN
# freq                                             292                     148
#
#           MENU_TYPE                    UNITS EMPLOYEES YEARS_IN_BUSINESS  \
# count          1000                     1000      1000              1000
# unique           45                        6         6                 2
# top     VARIED MENU  INDEPENDENT (1-9 UNITS)  10 TO 19      5 YEARS PLUS
# ...

# %% [markdown]
# ## Non-Commertial Data

# %%
noncommercial_data = pd.read_excel(r"D:\Data_analysis_Projects\Saun's company_Food service_ Casestudy\Data\Non Commercial.xlsx")

# %%
noncommercial_data.head()
# Out:
#                                     NAME             ADDRESS     CITY STATE  \
# 0       HERITAGE HALL NORTH NURSING HOME        55 COOPER ST   AGAWAM    MA
# 1  AGAWAM COUNCIL ON AGING SENIOR CENTER  68 MEADOWBROOK MNR   AGAWAM    MA
# 2       CENTER FOR EXTENDED CARE-AMHERST   150 UNIVERSITY DR  AMHERST    MA
# 3                      HAMPSHIRE COLLEGE         893 WEST ST  AMHERST    MA
# 4            UNIVERSITY OF MASSACHUSETTS        168 WHITMORE  AMHERST    MA
#
#     ZIP  ZIP_PLUS4  COUNTY_CODE COUNTY_NAME     MSA  \
# 0  1001     2149.0        25013     HAMPDEN  1122.0
# 1  1001     3126.0        25013     HAMPDEN  1122.0
# 2  1002     2232.0        25015   HAMPSHIRE  8000.0
# 3  1002     3372.0        25015   HAMPSHIRE  8000.0
# 4  1003        NaN        25015   HAMPSHIRE     NaN
#
#                                     MARKET_SEGMENT  ... ENROLLMENT_RANGE  \
# 0                                     NURSING HOME  ...   NOT APPLICABLE
# ...

# %% [markdown]
# ## Retail store

# %%
Retail_store = pd.read_excel(r"D:\Data_analysis_Projects\Saun's company_Food service_ Casestudy\Data\Retail Stores.xlsx")

# %%
Retail_store.head()
# Out:
#                         .       CITY STATE    ZIP  ZIP_PLUS4  COUNTY_CODE  \
# 0            AZON LIQUORS     AGAWAM    MA   1001     1530.0      25013.0
# 1  CUSTOM WINE ONLINE LLC  COVINGTON    KY  41011     2487.0      21117.0
# 2                      BP  COVINGTON    KY  41011     1441.0      21117.0
# 3  DICK'S WINES & LIQUORS  COVINGTON    KY  41011     1528.0      21117.0
# 4    END OF LINE BEVERAGE  FT WRIGHT    KY  41011     2602.0      21117.0
#
#   COUNTY_NAME     MSA market_segment2                    units  ...  \
# 0     HAMPDEN  1122.0   LIQUOR STORES  INDEPENDENT (1-9 UNITS)  ...
# 1      KENTON  1642.0   LIQUOR STORES  INDEPENDENT (1-9 UNITS)  ...
# 2      KENTON  1642.0    GAS STATIONS               501+ UNITS  ...
# 3      KENTON  1642.0   LIQUOR STORES  INDEPENDENT (1-9 UNITS)  ...
# 4      KENTON  1642.0   LIQUOR STORES  INDEPENDENT (1-9 UNITS)  ...
#
#                       years_in_business             annual_sales  \
# ...

# %%
# checking some information of retail store
Retail_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   .                              1001 non-null   object
#  1   CITY                           1001 non-null   object
#  2   STATE                          1001 non-null   object
#  3   ZIP                            1001 non-null   int64
#  4   ZIP_PLUS4                      909 non-null    float64
#  5   COUNTY_CODE                    974 non-null    float64
#  6   COUNTY_NAME                    974 non-null    object
#  7   MSA                            386 non-null    float64
#  8   market_segment2                1001 non-null   object
#  9   units                          1001 non-null   object
#  10  EMPLOYEES                      1001 non-null   object
#  11  years_in_business              1001 non-null   object
# ...

# %%
# checking some General statistics of Retail store
Retail_store.describe()
# Out:
#                 ZIP    ZIP_PLUS4   COUNTY_CODE          MSA  \
# count   1001.000000   909.000000    974.000000   386.000000
# mean   37817.855145  5409.502750  20005.546201  2163.264249
# std    11072.760413  3297.430341   3602.260722   873.650777
# min     1001.000000   127.000000   9003.000000  1122.000000
# 25%    41042.000000  1874.000000  21037.000000  1642.000000
# 50%    41501.000000  5419.000000  21117.000000  1642.000000
# 75%    42050.000000  8804.000000  21159.000000  3280.000000
# max    42301.000000  9998.000000  25027.000000  8000.000000
#
#        AVERAGE_DAILY_CENSUS
# count            255.000000
# mean             104.827059
# std               67.205879
# min                9.000000
# 25%               67.500000
# 50%              102.000000
# 75%              128.500000
# max              757.500000

# %%
Retail_store.describe(include="object")
# Out:
#                  .           CITY STATE COUNTY_NAME  \
# count         1001           1001  1001         974
# unique         783            232     3          58
# top     SAVE-A-LOT  BOWLING GREEN    KY      KENTON
# freq            39             58   896          82
#
#                                      market_segment2                    units  \
# count                                           1001                     1001
# unique                                             9                        5
# top     GROCERY STORES (LIMITED CHANNEL DISTRIBUTOR)  INDEPENDENT (1-9 UNITS)
# freq                                             513                      828
#
#        EMPLOYEES                     years_in_business annual_sales  \
# count       1001                                  1001         1001
# unique         6                                     3            6
# top       1 TO 4  UNCODED / DATA CURRENTLY UNAVAILABLE   <=$500,000
# ...
